# %% [markdown]
# # Colab-ready run notebook\nThis notebook mounts Drive, installs requirements, unzips project (if zipped) and provides cells to run preprocessing, training, inference and report generation.

# %%
from google.colab import drive\ndrive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/NCCT_Segmentation_Final || %cd /content/drive/MyDrive/NCCT_Segmentation_Final

# %%
# !pip install -r requirements.txt

# %%
# Example preprocess (update paths as needed)\n!python preprocess.py --input_dir data/raw --output_dir data/nifti --spacing 1.0 1.0 5.0

# %%
# Train segmentation\n!python train.py --config configs/config.json

# %%
# Train classifier (optional)\n!python train_classifier.py --config configs/config.json

# %%
# Inference example\n!python inference.py --model checkpoints/best.pth --input data/nifti --output_dir results

# %%
# Generate report for a single case\n!python report_generator.py --mask results/patient.mask.nii.gz --out results/patient_report.txt
